# %%
import pandas as pd

# %%
data=pd.read_csv('Employee_Salary_Dataset.csv')

# %%
import matplotlib.pyplot as plt

# %%
data.plot(x='ID',y='Salary',style='o')
# Out:
# <AxesSubplot:xlabel='ID'>

# %%
plt.xlabel('ID')
plt.ylabel('Salary')
plt.show()

# %%
data.plot(x='ID',y='Salary',style='o')
plt.xlabel('ID')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_'ID', y_, color='red')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 plt.scatter(X, y, color='red')
#
# NameError: name 'X' is not defined

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %% [raw]
# regressor.fit(x,y)

# %%
pred=regressor.predict(ID)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 pred=regressor.predict(ID)
#
# NameError: name 'ID' is not defined

# %%
import numpy as np

# %%
data.head()
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000

# %%
data.shape
# Out:
# (35, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                35 non-null     int64
#  1   Experience_Years  35 non-null     int64
#  2   Age               35 non-null     int64
#  3   Gender            35 non-null     object
#  4   Salary            35 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.5+ KB

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=42)

# %%
from sklearn.model_selection import train_test_split

# %%
x=data['ID']
y=data['Salary']

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import sklearn.metrics as sm
import matplotlib.pyplot as plt

# %%
X_train = np.array(X_train).reshape((len(X_train),1))
y_train = np.array(y_train).reshape((len(y_train),1))

X_test = np.array(X_test).reshape(len(X_test), 1)
y_test = np.array(y_test).reshape(len(y_test), 1)

# %%
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_train)

plt.figure()
plt.scatter(X_train, y_train, color='blue', label="True Value")
plt.plot(X_train, y_train_pred, color='black', linewidth=2, label="Prediction")
plt.xlabel("ID")
plt.ylabel("Salary")
plt.title('Empolyee Id vs Salary')
plt.legend()
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                35 non-null     int64
#  1   Experience_Years  35 non-null     int64
#  2   Age               35 non-null     int64
#  3   Gender            35 non-null     object
#  4   Salary            35 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.5+ KB

# %%
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_test_pred), 2))
print("Explain variance score =", round(sm.explained_variance_score(y_test, y_test_pred), 2))
print("R2 score =", round(sm.r2_score(y_test, y_test_pred), 2))
# Out:
# Mean squared error = 8830056578678.2
# Explain variance score = -0.71
# R2 score = -2.12

# %%
y_test_pred = model.predict(X_test)
